# %% [markdown]
# # Data Exploration of [Natural Areas and Wildlife Sanctuaries](https://egis-lacounty.hub.arcgis.com/datasets/002f1e2ac60e427f892d68270d4f1f59/explore)
#
# This is a dataset of locations of natural areas and wildlife sanctuaries in Los Angeles County. From the website: "This dataset is maintained through the County of Los Angeles Location Management System. The Location Management System is used by the County of Los Angeles GIS Program to maintain a single, comprehensive geographic database of locations countywide." I am interested in seeing how these natural areas are dispersed throughout the county.
#
#
# ## What am I Doing?

# %% [markdown]
# Importing data [from this source](https://egis-lacounty.hub.arcgis.com/datasets/002f1e2ac60e427f892d68270d4f1f59/explore)
#
# First imported geopandas:

# %%
import geopandas as gpd
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# next imported my csv file that I refer to as "nature"

# %%
nature = gpd.read_file('Natural_Areas_and_Wildlife_Sanctuaries.zip')

# %% [markdown]
# ##Conducting data exploration, with the following commands:<br>
# <br>
# type<br>
# .shape<br>
# .info<br>
# .head()<br>
# .plot()<br>
# .value_counts()<br>
# run a query on the data that filters it in some way<br>

# %%
# what type of data is this?
type(nature)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# how many rowas and columns in my data?
nature.shape
# Out:
# (167, 32)

# %% [markdown]
# My data has 167 rows and 32 columns to the dataset.

# %%
# more info on my dataset
nature.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   X             167 non-null    object
#  1   Y             167 non-null    object
#  2   OBJECTID      167 non-null    object
#  3   source        167 non-null    object
#  4   ext_id        167 non-null    object
#  5   cat1          167 non-null    object
#  6   cat2          167 non-null    object
#  7   cat3          167 non-null    object
#  8   org_name      167 non-null    object
#  9   Name          167 non-null    object
#  10  addrln1       167 non-null    object
#  11  addrln2       167 non-null    object
#  12  city          167 non-null    object
#  13  state         167 non-null    object
#  14  hours         167 non-null    object
#  15  phones        167 non-null    object
#  16  url           167 non-null    object
#  17  info1         167 non-null    object
# ...

# %%
#last 5 rows of my data
nature.tail()
# Out:
#                      X                 Y OBJECTID  \
# 162  -13164011.2928774  4125698.15114649    72627
# 163  -13103231.9119048  4099848.10380663    72635
# 164  -13110571.3260942  4133871.18410941    72639
# 165  -13173605.1983744  4064920.40577966    72668
# 166   -13116814.192174  4110384.69153776    72710
#
#                                            source ext_id                 cat1  \
# 162  LA County Department of Parks and Recreation         Arts and Recreation
# 163  LA County Department of Parks and Recreation         Arts and Recreation
# 164  LA County Department of Parks and Recreation         Arts and Recreation
# 165  LA County Department of Parks and Recreation         Arts and Recreation
# 166                                                       Arts and Recreation
#
#                                        cat2 cat3 org_name  \
# 162  Natural Areas and Wildlife Sanctuaries
# 163  Natural Areas and Wildlife Sanctuaries
# ...

# %%
# first 5 rows of my dataset
nature.head()
# Out:
#                    X                 Y OBJECTID  \
# 0  -13171103.2159839  3990742.60716074     1685
# 1  -13163237.2315769   4027478.3387638     1753
# 2  -13190121.4585182  4039094.99590009     2018
# 3  -13120082.9643408  4084607.44687992    13024
# 4  -13184701.8412871  4026048.15405427    13048
#
#                                         source ext_id                 cat1  \
# 0  LA County Department of Beaches and Harbors         Arts and Recreation
# 1                 LA City Recreation and Parks         Arts and Recreation
# 2                                          211         Arts and Recreation
# 3                     Current Services Locator         Arts and Recreation
# 4  LA County Department of Beaches and Harbors         Arts and Recreation
#
#                                      cat2        cat3  \
# 0  Natural Areas and Wildlife Sanctuaries
# 1  Natural Areas and Wildlife Sanctuaries
# 2  Natural Areas and Wildlife Sanctuaries  Open Space
# ...

# %%
# counting unqiue values in the dataset
nature['source'].value_counts()
# Out:
# HSIP Freedom Gnis_cultural_fe                   53
# LA City Recreation and Parks                    39
# LA County Department of Beaches and Harbors     28
# LA County Department of Parks and Recreation    15
# HSIP Freedom Gnis_admin_featu                   14
# 211                                              9
# Current Services Locator                         5
#                                                  3
# LA County Parks and Recreation                   1
# Name: source, dtype: int64

# %% [markdown]
# interesting... so this tells us that the largest contributor of data to this set is HSIP Freedom Gnis_cultural_fe ( HSIP Freedom, led by the Department of Homeland Security (DHS), is a license free subset of HSIP Gold)

# %%
# counting unqiue values in the dataset
nature['cat2'].value_counts()
# Out:
# Natural Areas and Wildlife Sanctuaries    167
# Name: cat2, dtype: int64

# %% [markdown]
# so it looks like the only value in the cat2 column is "Natural Areas and Wildlife Sanctuaries"

# %%
# counting unqiue values in the dataset
nature['cat1'].value_counts()
# Out:
# Arts and Recreation    167
# Name: cat1, dtype: int64

# %% [markdown]
# so it looks like the only value in the cat2 column is "arts and recreation"

# %%
#viewing my data in a table
nature
# Out:
#                      X                 Y OBJECTID  \
# 0    -13171103.2159839  3990742.60716074     1685
# 1    -13163237.2315769   4027478.3387638     1753
# 2    -13190121.4585182  4039094.99590009     2018
# 3    -13120082.9643408  4084607.44687992    13024
# 4    -13184701.8412871  4026048.15405427    13048
# ..                 ...               ...      ...
# 162  -13164011.2928774  4125698.15114649    72627
# 163  -13103231.9119048  4099848.10380663    72635
# 164  -13110571.3260942  4133871.18410941    72639
# 165  -13173605.1983744  4064920.40577966    72668
# 166   -13116814.192174  4110384.69153776    72710
#
#                                            source ext_id                 cat1  \
# 0     LA County Department of Beaches and Harbors         Arts and Recreation
# 1                    LA City Recreation and Parks         Arts and Recreation
# 2                                             211         Arts and Recreation
# ...

# %%
# time to plot my data!
nature.plot()
# Out:
# <AxesSubplot:>

# %%
re-importing as a shape file resulted in this map

# %%
# filtering with query method to see which rows are sourced from the department of beaches and harbors
nature.query('source == "LA County Department of Beaches and Harbors"')

# %% [markdown]
# So we end up with only rows that have the department of beaches and harbors after running this query that filters the data
